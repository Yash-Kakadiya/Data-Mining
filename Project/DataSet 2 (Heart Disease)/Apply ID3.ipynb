# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Data Mining</b></center>
# <center><b><h1>Dataset 2: Heart Disease</b></center>
# <center><b><h1>Implement Decision Tree(ID3).</b></center>
# <center><b><h1>¥@$# Kakadiya | 23010101121 | 30/07/2025</b></center>
# <pre>

# %% [markdown]
# # Implement Decision Tree(ID3) in python
# Uses Information Gain to choose the best feature to split.
#
# Recursively builds the tree until stopping conditions are met.

# %% [markdown]
# 1) Calculate Entropy for the dataset.<BR>
# 2) Calculate Information Gain for each feature. <BR>
# 3) Choose the feature with maximum Information Gain. <BR>
# 4) Split dataset into subsets for that feature. <BR>
# 5) Repeat recursively until: <BR>
#
# All samples in a node have the same label.<BR>
# No features are left.<BR>
# No data is left.

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ##  import Pandas, Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##  Create Following Data

# %%
data = pd.read_csv('../data/raw/Heart.csv')
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %% [markdown]
# ## Now Define Function to  Calculate Entropy

# %%
def entropy(target_col):
    elements, counts = np.unique(target_col, return_counts=True)
    entropy = -np.sum([(counts[i]/np.sum(counts))*np.log2(counts[i]/np.sum(counts)) for i in range(len(elements))])
    return entropy

# %% [markdown]
# ## Testing of Above Function -
# y = np.array(['Yes', 'No',   'Yes', 'Yes'])
# Function Call - > entropy(y))
#
# output - 0.8112781244591328

# %%
y = np.array(['Yes', 'No',   'Yes', 'Yes'])
print(entropy(y))
# Out:
# 0.8112781244591328

# %% [markdown]
# ## Define function to Calculate Information Gain

# %%
def information_gain(data, split_attribute_name, target_name):
    """
    Calculate the information gain of a dataset for a given attribute.
    """
    # Calculate the entropy of the whole dataset
    total_entropy = entropy(data[target_name])

    # Calculate the entropy of the dataset after splitting by the attribute
    values, counts = np.unique(data[split_attribute_name], return_counts=True)
    weighted_entropy = np.sum([(counts[i]/np.sum(counts))*entropy(data.where(data[split_attribute_name]==values[i]).dropna()[target_name]) for i in range(len(values))])

    # Calculate the information gain
    information_gain = total_entropy - weighted_entropy
    return information_gain

# %% [markdown]
# ## Testing of Above Function

# %%
print(information_gain(data, 'cp', 'target'))
# Out:
# 0.20848408129015084

# %% [markdown]
# ## Implement ID3 Algo

# %%
def id3(data, features, target='target'):
    # If all labels are same → return the label
    if len(np.unique(data[target])) == 1:
        return np.unique(data[target])[0]

    # If no features left → return majority label
    elif len(features) == 0:
        return np.unique(data[target])[np.argmax(np.unique(data[target], return_counts=True)[1])]

    else:
        # Choose best feature
        item_values = [information_gain(data, feature, target) for feature in features]
        best_feature_index = np.argmax(item_values)
        best_feature = features[best_feature_index]

        # Create tree structure
        tree = {best_feature: {}}

        # Remove best feature from feature list
        features = [i for i in features if i != best_feature]

        # For each value of best feature → branch
        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3(sub_data, features, target)
            tree[best_feature][value] = subtree

        return tree

# %% [markdown]
# ## Use ID3

# %%
features = data.columns[:-1]  # Exclude the target column
tree = id3(data, features)

# %% [markdown]
# ## Print Tree

# %%
print(tree)
# Out:
# {'chol': {np.int64(126): np.float64(1.0), np.int64(131): np.float64(0.0), np.int64(141): np.float64(1.0), np.int64(149): {'age': {np.float64(49.0): np.float64(0.0), np.float64(71.0): np.float64(1.0)}}, np.int64(157): np.float64(1.0), np.int64(160): np.float64(1.0), np.int64(164): np.float64(0.0), np.int64(166): np.float64(0.0), np.int64(167): np.float64(0.0), np.int64(168): np.float64(1.0), np.int64(169): np.float64(0.0), np.int64(172): np.float64(0.0), np.int64(174): np.float64(0.0), np.int64(175): np.float64(1.0), np.int64(176): np.float64(0.0), np.int64(177): {'age': {np.float64(43.0): np.float64(0.0), np.float64(46.0): np.float64(1.0), np.float64(59.0): np.float64(0.0), np.float64(65.0): np.float64(1.0)}}, np.int64(178): np.float64(1.0), np.int64(180): np.float64(1.0), np.int64(182): np.float64(1.0), np.int64(183): np.float64(1.0), np.int64(184): np.float64(0.0), np.int64(185): np.float64(0.0), np.int64(186): np.float64(1.0), np.int64(187): np.float64(0.0), np.int64(188): np.float64(0.0), np.int64(192): np.float64(1.0), np.int64(193): {'age': {np.float64(56.0): np.float64(1.0), np.float64(68.0): np.float64(0.0)}}, np.int64(195): np.float64(1.0), np.int64(196): np.float64(1.0), np.int64(197): {'age': {np.float64(44.0): np.float64(0.0), np.float64(46.0): np.float64(1.0), np.float64(53.0): np.float64(1.0), np.float64(58.0): np.float64(1.0), np.float64(63.0): np.float64(0.0), np.float64(76.0): np.float64(1.0)}}, np.int64(198): {'age': {np.float64(35.0): np.float64(0.0), np.float64(41.0): np.float64(1.0)}}, np.int64(199): np.float64(1.0), np.int64(200): np.float64(0.0), np.int64(201): np.float64(1.0), np.int64(203): {'age': {np.float64(41.0): np.float64(1.0), np.float64(53.0): np.float64(0.0), np.float64(61.0): np.float64(0.0)}}, np.int64(204): {'age': {np.float64(29.0): np.float64(1.0), np.float64(41.0): np.float64(1.0), np.float64(46.0): np.float64(1.0), np.float64(47.0): np.float64(1.0), np.float64(52.0): np.float64(0.0), np.float64(59.0): np.float64(0.0)}}, np.int64(205): {'age': {np.float64(52.0): np.float64(1.0), np.float64(55.0): np.float64(0.0)}}, np.int64(206): np.float64(0.0), np.int64(207): {'age': {np.float64(57.0): np.float64(1.0), np.float64(61.0): np.float64(0.0)}}, np.int64(208): np.float64(1.0), np.int64(209): np.float64(1.0), np.int64(210): np.float64(1.0), np.int64(211): np.float64(1.0), np.int64(212): {'age': {np.float64(52.0): np.float64(0.0), np.float64(59.0): np.float64(1.0), np.float64(64.0): np.float64(0.0), np.float64(66.0): np.float64(0.0), np.float64(67.0): np.float64(0.0)}}, np.int64(213): np.float64(1.0), np.int64(214): np.float64(1.0), np.int64(215): np.float64(1.0), np.int64(216): {'age': {np.float64(53.0): np.float64(1.0), np.float64(58.0): np.float64(0.0)}}, np.int64(217): np.float64(0.0), np.int64(218): np.float64(0.0), np.int64(219): {'age': {np.float64(39.0): np.float64(0.0), np.float64(44.0): np.float64(1.0), np.float64(50.0): np.float64(1.0)}}, np.int64(220): np.float64(1.0), np.int64(221): np.float64(1.0), np.int64(222): np.float64(1.0), np.int64(223): {'age': {np.float64(40.0): np.float64(0.0), np.float64(52.0): np.float64(1.0), np.float64(67.0): np.float64(1.0)}}, np.int64(224): np.float64(0.0), np.int64(225): np.float64(0.0), np.int64(226): np.float64(1.0), np.int64(227): np.float64(1.0), np.int64(228): {'sex': {np.float64(0.0): np.float64(0.0), np.float64(1.0): np.float64(1.0)}}, np.int64(229): np.float64(0.0), np.int64(230): np.float64(0.0), np.int64(231): {'age': {np.float64(38.0): np.float64(0.0), np.float64(46.0): np.float64(0.0), np.float64(62.0): np.float64(1.0)}}, np.int64(232): {'age': {np.float64(54.0): np.float64(1.0), np.float64(57.0): np.float64(0.0)}}, np.int64(233): {'age': {np.float64(44.0): np.float64(1.0), np.float64(50.0): np.float64(0.0), np.float64(52.0): np.float64(1.0), np.float64(63.0): np.float64(1.0)}}, np.int64(234): {'age': {np.float64(45.0): np.float64(1.0), np.float64(53.0): np.float64(1.0), np.float64(58.0): np.float64(0.0), np.float64(59.0): np.float64(1 ...

# %% [markdown]
# ## Extra: Create Predict Function

# %%
def predict(tree, sample):
    # If the node is a leaf node, return the label
    if not isinstance(tree, dict):
        return tree

    # Get the attribute to split on
    attribute = list(tree.keys())[0]
    attribute_value = sample[attribute]

    # Traverse the tree based on the attribute value
    if attribute_value in tree[attribute]:
        return predict(tree[attribute][attribute_value], sample)
    else:
        # Handle cases where the attribute value is not in the tree (e.g., return majority class of the current node's data, or a default value)
        # For simplicity, this implementation will return None or raise an error.
        # A more robust implementation would handle unknown values.
        return None # Or raise an error

# %% [markdown]
# ##  Extra: Predict for a sample

# %%
sample = {
    'age': 55,
    'sex': 1,
    'cp': 0,
    'trestbps': 140,
    'chol': 220,
    'fbs': 0,
    'restecg': 1,
    'thalach': 150,
    'exang': 1,
    'oldpeak': 0.8,
    'slope': 2,
    'ca': 2,
    'thal': 3
}

# %%
prediction = predict(tree, sample)
print("Prediction:", prediction)
# Out:
# Prediction: 1.0

# %% [markdown]
# # Task
# Complete the Python notebook to implement and test the ID3 decision tree algorithm, including functions for entropy, information gain, ID3 tree building, and prediction.

# %% [markdown]
# ## Complete `entropy` function
#
# ### Subtask:
# Implement the calculation of entropy in the provided `entropy` function.

# %% [markdown]
# **Reasoning**:
# Implement the entropy function based on the provided instructions to calculate the entropy of a given target variable.

# %% [markdown]
# ## Complete `information_gain` function
#
# ### Subtask:
# Implement the calculation of information gain in the provided `information_gain` function.
